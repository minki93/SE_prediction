# %% [markdown]
# # Analyzing the SIDER 4.1 data
#
# + http://sideeffects.embl.de/
# + http://thinklab.com/d/30#4

# %%
import csv
import gzip
import collections

# %%
import pandas as pd

# %% [markdown]
# ## STITCH to DrugBank mapping utilities

# %%
def stitch_flat_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:]) - 1e8

def stitch_stereo_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:])

# %%
# Read DrugBank terms
url = 'https://raw.githubusercontent.com/dhimmel/drugbank/3e87872db5fca5ac427ce27464ab945c0ceb4ec6/data/drugbank.tsv'
drugbank_df = pd.read_table(url)[['drugbank_id', 'name']].rename(columns={'name': 'drugbank_name'})

# Pubchem to DrugBank mapping
url = 'https://raw.githubusercontent.com/dhimmel/drugbank/3e87872db5fca5ac427ce27464ab945c0ceb4ec6/data/mapping/pubchem.tsv'
drugbank_map_df = pd.read_table(url)

# %%
drugbank_map_df
# Out:
#        drugbank_id  pubchem_id
# 0          DB00014    11980055
# 1          DB00014    11981235
# 2          DB00014    11982741
# 3          DB00014    16052011
# 4          DB00014    23581804
# ...            ...         ...
# 204704     DB09028    74070157
# 204705     DB09028    74834862
# 204706     DB09028    77513518
# 204707     DB09028    87355970
# 204708     DB09028    87644641
#
# [204709 rows x 2 columns]

# %% [markdown]
# ## meddra_freq.tsv.gz

# %%
freq_df = pd.read_table("../Data/Original/meddra_freq.tsv",header=None)
freq_df.columns = [
    'stitch_id_flat',
    'stitch_id_sterio',
    'umls_cui_from_label',
    'placebo',
    'frequency',
    'lower',
    'upper',
    'meddra_type',
    'umls_cui_from_meddra',
    'side_effect_name',
]
freq_df
# Out:
#        stitch_id_flat stitch_id_sterio umls_cui_from_label placebo frequency  \
# 0        CID100000085     CID000010917            C0000737     NaN       21%
# 1        CID100000085     CID000010917            C0000737     NaN       21%
# 2        CID100000085     CID000010917            C0000737     NaN       21%
# 3        CID100000085     CID000010917            C0000737     NaN        5%
# 4        CID100000085     CID000010917            C0000737     NaN        5%
# ...               ...              ...                 ...     ...       ...
# 291627   CID171306834     CID071306834            C2830004     NaN        5%
# 291628   CID171306834     CID071306834            C2830004     NaN        5%
# 291629   CID171306834     CID071306834            C2830004     NaN        5%
# 291630   CID171306834     CID071306834            C2830004     NaN        9%
# 291631   CID171306834     CID071306834            C2830004     NaN        9%
#
#         lower  upper meddra_type umls_cui_from_meddra       side_effect_name
# 0        0.21   0.21         LLT             C0000737         Abdominal pain
# 1        0.21   0.21          PT             C0000737         Abdominal pain
# 2        0.21   0.21          PT             C0687713  Gastrointestinal pain
# 3        0.05   0.05         LLT             C0000737         Abdominal pain
# 4        0.05   0.05          PT             C0000737         Abdominal pain
# ...       ...    ...         ...                  ...                    ...
# 291627   0.00   0.05          PT             C2830004             Somnolence
# 291628   0.05   0.05         LLT             C2830004             Somnolence
# 291629   0.05   0.05          PT             C2830004             Somnolence
# 291630   0.09   0.09         LLT             C2830004             Somnolence
# 291631   0.09   0.09          PT             C2830004             Somnolence
#
# [291632 rows x 10 columns]

# %% [markdown]
# ## meddra_all_se.tsv.gz

# %%
se_df = pd.read_table("../Data/Original/meddra_all_se.tsv",header=None)
se_df.columns = [
    'stitch_id_flat',
    'stitch_id_sterio',
    'umls_cui_from_label',
    'meddra_type',
    'umls_cui_from_meddra',
    'side_effect_name',
]
se_df['pubchem_id'] = se_df.stitch_id_sterio.map(stitch_stereo_to_pubchem)
se_df = drugbank_map_df.merge(se_df)
se_df
# Out:
#        drugbank_id  pubchem_id stitch_id_flat stitch_id_sterio  \
# 0          DB00014       47725   CID100047725     CID000047725
# 1          DB00014       47725   CID100047725     CID000047725
# 2          DB00014       47725   CID100047725     CID000047725
# 3          DB00014       47725   CID100047725     CID000047725
# 4          DB00014       47725   CID100047725     CID000047725
# ...            ...         ...            ...              ...
# 301158     DB09020        2391   CID100002391     CID000002391
# 301159     DB09020        2391   CID100002391     CID000002391
# 301160     DB09020        2391   CID100002391     CID000002391
# 301161     DB09020        2391   CID100002391     CID000002391
# 301162     DB09020        2391   CID100002391     CID000002391
#
#        umls_cui_from_label meddra_type umls_cui_from_meddra  \
# 0                 C0000737         LLT             C0000737
# 1                 C0000737          PT             C0687713
# 2                 C0000737          PT             C0000737
# 3                 C0002170         LLT             C0002170
# 4                 C0002170          PT             C0002170
# ...                    ...         ...                  ...
# 301158            C0948733          PT             C0159066
# 301159            C1321898         LLT             C1321898
# 301160            C1321898          PT             C0018932
# 301161            C2242737         LLT             C2242737
# 301162            C2242737          PT             C2242737
#
#              side_effect_name
# 0              Abdominal pain
# 1       Gastrointestinal pain
# 2              Abdominal pain
# 3                    Alopecia
# 4                    Alopecia
# ...                       ...
# 301158     Abdominal rigidity
# 301159         Blood in stool
# 301160          Haematochezia
# 301161   Anorectal discomfort
# 301162   Anorectal discomfort
#
# [301163 rows x 8 columns]

# %%
se_df = se_df[['drugbank_id','pubchem_id', 'umls_cui_from_meddra', 'side_effect_name']]
se_df = se_df.dropna()
se_df = se_df.drop_duplicates(['drugbank_id', 'umls_cui_from_meddra'])
se_df = drugbank_df.merge(se_df)
se_df = se_df.sort_values(['drugbank_name', 'side_effect_name'])
print(len(se_df))
se_df.to_csv("../Data/sider_data.csv",index=False)
# Out:
# 153663

# %%
se_df
# Out:
#        drugbank_id                                      drugbank_name  \
# 146269     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 146270     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 146524     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 146622     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# 146645     DB07768  (10ALPHA,13ALPHA,14BETA,17ALPHA)-17-HYDROXYAND...
# ...            ...                                                ...
# 138639     DB05738                         vapitadine dihydrochloride
# 138654     DB05738                         vapitadine dihydrochloride
# 138650     DB05738                         vapitadine dihydrochloride
# 138651     DB05738                         vapitadine dihydrochloride
# 138652     DB05738                         vapitadine dihydrochloride
#
#         pubchem_id umls_cui_from_meddra          side_effect_name
# 146269        6013             C0000729          Abdominal cramps
# 146270        6013             C0000737            Abdominal pain
# 146524        6013             C0232492      Abdominal pain upper
# 146622        6013             C0740651         Abdominal symptom
# 146645        6013             C0877331  Abnormal clotting factor
# ...            ...                  ...                       ...
# 138639         312             C0015230                      Rash
# 138654         312             C0234233                Tenderness
# 138650         312             C0041582                     Ulcer
# 138651         312             C0042487         Venous thrombosis
# 138652         312             C0042963                  Vomiting
#
# [153663 rows x 5 columns]
